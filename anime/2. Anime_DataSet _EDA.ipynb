# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Now i have anime.csv
# i do this step because after filtering our data is Still too big for best recommendation
#
# So i have to do same steps again for reducing our data .

# %%
data = pd.read_csv("C:/Machine Learning/anime_recommendation_system/anime.csv")
data
# Out:
#       Unnamed: 0    uid                                              title  \
# 0              0  28891                            Haikyuu!! Second Season
# 1              1  23273                            Shigatsu wa Kimi no Uso
# 2              2  34599                                      Made in Abyss
# 3              3   5114                   Fullmetal Alchemist: Brotherhood
# 4              4  31758                   Kizumonogatari III: Reiketsu-hen
# ...          ...    ...                                                ...
# 7679        7679  10075                                        Naruto x UT
# 7680        7680  35828                                   Miira no Kaikata
# 7681        7681  10378                             Shinryaku!? Ika Musume
# 7682        7682  33082                      Kingsglaive: Final Fantasy XV
# 7683        7683  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                synopsis  \
# ...

# %%
data["fscore"] = data["score"].astype(str)

# %%
def clean1(anime):
    y = ""
    for i in anime[0]:
        y=(i)
    return y

# %%
data["fscore"] = data["fscore"].apply(clean1)

# %%
data[data["fscore"] == "6"]
# Out:
#       Unnamed: 0    uid                                              title  \
# 1000        1000  37948                                           Hentatsu
# 1001        1001  22831                     Abarenbou Rikishi!! Matsutarou
# 1002        1002  38154                  3-gatsu no Lion: Ugoku! Nya Shogi
# 1003        1003  25875                                 Wake Up, Girl Zoo!
# 1004        1004  28085                                     Wonder (Movie)
# ...          ...    ...                                                ...
# 7198        7198   8368  Crayon Shin-chan Movie 17: Otakebe! Kasukabe Y...
# 7199        7199  30376         Isshuukan Friends.: Tomodachi to no Omoide
# 7200        7200  34535                                  Koisuru Shirokuma
# 7201        7201   2403                               Kodomo no Jikan (TV)
# 7202        7202   5914                                           Kanamemo
#
#                                                synopsis  \
# ...

# %%
a = data[data['fscore'] == "6"].index
data.drop(index=a,inplace=True)

# %%
data
# Out:
#       Unnamed: 0    uid                                              title  \
# 0              0  28891                            Haikyuu!! Second Season
# 1              1  23273                            Shigatsu wa Kimi no Uso
# 2              2  34599                                      Made in Abyss
# 3              3   5114                   Fullmetal Alchemist: Brotherhood
# 4              4  31758                   Kizumonogatari III: Reiketsu-hen
# ...          ...    ...                                                ...
# 7679        7679  10075                                        Naruto x UT
# 7680        7680  35828                                   Miira no Kaikata
# 7681        7681  10378                             Shinryaku!? Ika Musume
# 7682        7682  33082                      Kingsglaive: Final Fantasy XV
# 7683        7683  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                synopsis  \
# ...

# %%
data1  = data.drop(columns=["fscore","Unnamed: 0"])
# data2  = data.drop(columns=["Unnamed: 0"])

# %%
# data2.to_csv('C:/Machine Learning/Ready anime_recommendation_system/animedata1.csv')

# %%
data1
# Out:
#         uid                                              title  \
# 0     28891                            Haikyuu!! Second Season
# 1     23273                            Shigatsu wa Kimi no Uso
# 2     34599                                      Made in Abyss
# 3      5114                   Fullmetal Alchemist: Brotherhood
# 4     31758                   Kizumonogatari III: Reiketsu-hen
# ...     ...                                                ...
# 7679  10075                                        Naruto x UT
# 7680  35828                                   Miira no Kaikata
# 7681  10378                             Shinryaku!? Ika Musume
# 7682  33082                      Kingsglaive: Final Fantasy XV
# 7683  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                synopsis  \
# 0     Following their participation at the Inter-Hig...
# 1     Music accompanies the path of the human metron...
# ...

# %%
data2 = data1.drop_duplicates() 
data2
# Out:
#         uid                                              title  \
# 0     28891                            Haikyuu!! Second Season
# 1     23273                            Shigatsu wa Kimi no Uso
# 2     34599                                      Made in Abyss
# 3      5114                   Fullmetal Alchemist: Brotherhood
# 4     31758                   Kizumonogatari III: Reiketsu-hen
# ...     ...                                                ...
# 7679  10075                                        Naruto x UT
# 7680  35828                                   Miira no Kaikata
# 7681  10378                             Shinryaku!? Ika Musume
# 7682  33082                      Kingsglaive: Final Fantasy XV
# 7683  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                synopsis  \
# 0     Following their participation at the Inter-Hig...
# 1     Music accompanies the path of the human metron...
# ...

# %%
data2["synopsis"][0]
# Out:
# "Following their participation at the Inter-High, the Karasuno High School volleyball team attempts to refocus their efforts, aiming to conquer the Spring tournament instead. When they receive an invitation from long-standing rival Nekoma High, Karasuno agrees to take part in a large training camp alongside many notable volleyball teams in Tokyo and even some national level players. By playing with some of the toughest teams in Japan, they hope not only to sharpen their skills, but also come up with new attacks that would strengthen them. Moreover, Hinata and Kageyama attempt to devise a more powerful weapon, one that could possibly break the sturdiest of blocks. Facing what may be their last chance at victory before the senior players graduate, the members of Karasuno's volleyball team must learn to settle their differences and train harder than ever if they hope to overcome formidable opponents old and new—including their archrival Aoba Jousai and its world-class setter Tooru Oikaw
# ...

# %%
data1.to_csv('reduce_anime.csv')

# %% [markdown]
# # Now i Have reduce_anime.csv
